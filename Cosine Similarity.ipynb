# %%
import sys

def cos(v1,v2):
    if len(v1)!=len(v2):
        print("Vectors are not of same length.")
        sys.exit(0)
    elif len(v1)==0 or len(v2)==0:
        print("Vectors of length 0 not allowed.")
        sys.exit(0)
    return np.dot(v1,v2)/(np.linalg.norm(v1)*np.linalg.norm(v2))

import numpy as np

v1=np.array(input("Enter vector 1 :").split(),dtype=float)
v2=np.array(input("Enter vector 2 :").split(),dtype=float)

print(v1,v2)

result=cos(v1,v2)
print(result)
# Out:
# [1 2 3] [3 6 9]
# 1.0
